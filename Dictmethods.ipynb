# %% [markdown]
# # Day 9
# # 13/11 2025

# %%
dic = {'a':10,'b':20,'c':30,'d':40}
print(dic.pop('a'))
print(dic)
# Out:
# 10
# {'b': 20, 'c': 30, 'd': 40}

# %%
dic1 = {'a':10,'b':20,'c':30,'d':40}
print(dic1.popitem())
# Out:
# ('d', 40)

# %%
print(dic1)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
dic1 = {'a':10,'b':20,'c':30,'d':40}
print(dic1)
dic1.clear()
print(dic1)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}
# {}

# %%
dic1 = {'a':10,'b':20,'c':30,'d':40}
a=dic1.get('a')
print(a)
# Out:
# 10

# %%
b=dic1.get('z',0)
print(b)
# Out:
# 0

# %%
dic1 = {'a':10,'b':20,'c':30,'d':40}
dic1.items()
# Out:
# dict_items([('a', 10), ('b', 20), ('c', 30), ('d', 40)])

# %%
for str1,num in dic1.items():
    print(str1,':',num)
# Out:
# a : 10
# b : 20
# c : 30
# d : 40

# %%
s = 'Welcome to python'
s.split()
# Out:
# ['Welcome', 'to', 'python']

# %%
s='Welcome,  to,  python and ,  bla,  bla   '
s.split(',')
# Out:
# ['Welcome', '  to', '  python and ', '  bla', '  bla   ']

# %%
s='Welcome,  to,  python and ,  bla,  bla   '
[x.strip() for x in s.split(',')]
# Out:
# ['Welcome', 'to', 'python and', 'bla', 'bla']

# %%
a='   Good'
print(a.strip())
a
# Out:
# Good
# '   Good'

# %%
s="  Hello World!   "
s.strip()
# Out:
# 'Hello World!'

# %%
s.lstrip()
# Out:
# 'Hello World!   '

# %%
s.rstrip()
# Out:
# '  Hello World!'

# %%
s="########this is an example#########"
s.strip('#')
# Out:
# 'this is an example'

# %%
s="########this is an example#########"
s.lstrip('#')
# Out:
# 'this is an example#########'

# %%
s.rstrip('#')
# Out:
# '########this is an example'

# %%
','.join(['apple','grape','banana'])
# Out:
# 'apple,grape,banana'

# %%
'-'.join('010.1234.5678'.split('.'))
# Out:
# '010-1234-5678'

# %%
''.join(['apple','grape','banana'])
# Out:
# 'applegrapebanana'

# %%
s="Hello world"
clist=list(s)
clist
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
''.join(clist)
# Out:
# 'Hello world'

# %%
a_string='Actions \n\t speak leader than words'
a_string
# Out:
# 'Actions \n\t speak leader than words'

# %%
print(a_string)
# Out:
# Actions
# 	 speak leader than words

# %%
word_list=a_string.split()
word_list
# Out:
# ['Actions', 'speak', 'leader', 'than', 'words']

# %%
refined_string=" ".join(word_list)
print(refined_string)
# Out:
# Actions speak leader than words

# %%
txt='123,456,789,999'v

rll=txt.replace(",","$")
rt1=txt.replace(",","",1)
rt2=txt.replace(",","",2)
rt3=txt.replace(",","",3)
print("Result:")
print(rll)
print(rt1)
print(rt2)
print(rt3)
# Out:
# Result:
# 123$456$789$999
# 123456,789,999
# 123456789,999
# 123456789999

# %%
keys=['a','b','c','d']
x=dict.fromkeys(keys)
x
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
keys=('a','b','c','d')
x=dict.fromkeys(keys)
x
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
y=dict.fromkeys(keys,100)
y
# Out:
# {'a': 100, 'b': 100, 'c': 100, 'd': 100}

# %%
from collections import defaultdict
keys=('a','b','c','d')
y=dict.fromkeys(keys,100)
y=defaultdict(int)

# %%
y['z']
# Out:
# 0

# %%
y
# Out:
# defaultdict(int, {'z': 0})

# %%
int()
# Out:
# 0

# %%
from collections import defaultdict

word = 'abcbaabca'
counter = defaultdict(int)
for letter in word:
    counter[letter]+=1
counter
# Out:
# defaultdict(int, {'a': 4, 'b': 3, 'c': 2})

# %%
x={'a':10,'b':20,'c':30,'d':40}
for key in x.keys():
    print(key,end=' ')
# Out:
# a b c d

# %%
x={'a':10,'b':20,'c':30,'d':40}
for value in x.values():
    print(value,end=' ')
# Out:
# 10 20 30 40
