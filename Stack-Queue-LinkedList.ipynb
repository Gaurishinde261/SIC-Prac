# %% [markdown]
# # 05/01/2026

# %% [markdown]
# # __Data-Structure & Algorithm__

# %% [markdown]
# ## Stack
# -- Stack is linear data structure that follows the principal of Last In First out(LIFO).
#
# **Stack operation**
#
# --push:add the element in stack
#
# --pop:Use to remove element from stack
#
# --isEmpty:Check if stack is empty
#
# --Isfull:check if stack is full

# %%
def Create_stack():
    stack =[]
    return stack
def Push(stack,data):
    stack.append(data)
    print("pushed data:",data)

def Stack_empty(stack):
    return len(stack) == 0

def stack_pop(stack):
    if(Stack_empty(stack)):
        return "stack is Empty"
    return stack.pop()

stack = Create_stack()
print(stack)
Push(stack,10)
Push(stack,20)
Push(stack,30)
print(stack)
print(Stack_empty(stack))
print(stack_pop(stack))

# working with isEmpty,isFull,Peek

class Stack:
    def __init__(self,size):
        self.size = size
        self.stack = []

    #Check stack is empty 
    def isEmpty(self):
        return len(self.stack) == 0

    #check stack is full
    def isFull(self):
        return len(self.stack) == self.size

    #adding item in stack
    def push(self,item):
        if self.isFull():
            return "stack is Full"
        else:
            self.stack.append(item)
            return (item,"Pushed in Stack")       

    #pop the element from stack



s = Stack(5)
print(s.isEmpty())
print(s.isFull())
print(s.push(3))
print(s.push(4))
print(s.isFull())
# Out:
# []
# pushed data: 10
# pushed data: 20
# pushed data: 30
# [10, 20, 30]
# False
# 30
# True
# False
# (3, 'Pushed in Stack')
# (4, 'Pushed in Stack')
# False

# %%
class stack:
    def __init__(self,size):
        self.size = size
        self.stack = []

    def viewStack(self,stack):
        return self.stack

    def isEmpty(self):
        return len(self.stack) == 0
        
    def isFull(self):
        return len(self.stack) == self.size

    def push(self,item):
        if self.isFull(

t = [(1,"Pass"),
     (2,"Fail"),
     (3,"Pass"),
     (4,"Fail")
    ]
for i in t:
    if i[0] == "Pass":

# %% [markdown]
# # Queue
# --Follow FIFO Principal
# #### ** Queue opertion**
#     Enqueue
#     Dequeue
#     isEmpty
#     isFull
#     Peek
#
# Types of Queue
#     1.simple queue
#     2.circular queue
#     3.priority queue
#     4.Double ended queue(Deque)

# %%
class queue:
    def __init__(self, size):
        self.size = size
        self.queue = [None]*size
        self.head = self.tail = -1
    
    def enqueue(self, ele):
        if self.tail == self.size - 1:
            return 'Queue is Full'
        elif self.head == -1:
            self.head = 0
            self.tail = 0
            self.queue[self.tail] = ele
        else:
            self.tail += 1
            self.queue[self.tail] = ele


    def dequeue(self):
        if self.head == -1:
            return 'Queue is Empty'
        ele = self.queue[self.head]
        if self.head == self.tail:
            self.head = self.tail = -1
        else:
            self.head += 1
        return ele

    def printQueue(self):
        if self.head == -1:
            print('Queue is Empty')
        else:
            for i in range(self.head, self.tail +1):
                print(self.queue[i], end=' ')
            print()

q1 = queue(5)
q1.enqueue(1)
q1.enqueue(2)
q1.enqueue(3)
q1.enqueue(4)
q1.enqueue(5)
q1.enqueue(6)

print(q1.dequeue())

q1.printQueue()
# Out:
# 1
# 2 3 4 5

# %%
a = 5
b = 5
a=b=5

print(a)
print(b)
print(id(a))
print(id(b))
# Out:
# 5
# 5
# 140727845823736
# 140727845823736

# %%
# Circular Queue
class CircularQueue:
    def __init__(self,size):
        self.size = size
        self.queue = [None] * size
        self.front = -1
        self.rear = -1

    #Check queue is full
    def is_full(self):
        return(self.rear + 1) % self.size == self.front


    #check queue is empty
    def is_empty(self):
        return self.front == -1

    #add element
    def enqueue(self,data):
        if self.is_full():
            print("Queue is full")
            return
        if self.is_empty():
            self.front = 0
        self.rear = (self.rear + 1) % self.size
        self.queue[self.rear] = data
        print("Add Element:",data)

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty")
            return
        data = self.queue[self.front]
        if self.front == self.rear:
            self.front = self.rear = -1
        else:
            self.front = (self.front + 1) % self.size
        print("Dequeued:",data)
        return data
    
            
    def display(self):
        if self.is_empty():
            print("Queue is empty")
            return
        i = self.front
        elements = []
        while True:
            elements.append(self.queue[i])
            if i == self.rear:
                break
            i = (i+1) % self.size
        print("Queue:",elements)


cq =CircularQueue(5)
cq.enqueue(10)
cq.enqueue(20)
cq.enqueue(30)
cq.enqueue(40)
cq.enqueue(50)
cq.display()
cq.dequeue()
cq.display()
cq.enqueue(60)
cq.display()
# Out:
# Add Element: 10
# Add Element: 20
# Add Element: 30
# Add Element: 40
# Add Element: 50
# Queue: [10, 20, 30, 40, 50]
# Dequeued: 10
# Queue: [20, 30, 40, 50]
# Add Element: 60
# Queue: [20, 30, 40, 50, 60]

# %%
# priority Queue
from queue import PriorityQueue
print(dir(PriorityQueue))
pq = PriorityQueue()
pq.put((2,"clean room"))
pq.put((1,"do homework"))
pq.put((3,"Play Game"))

while not pq.empty():
    priority,task = pq.get()
    print(task)
# Out:
# ['__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_get', '_init', '_put', '_qsize', 'empty', 'full', 'get', 'get_nowait', 'join', 'put', 'put_nowait', 'qsize', 'shutdown', 'task_done']
# do homework
# clean room
# Play Game

# %%
patients = [(1,"Patients with heart attack"),
            (3,"Patients with cold"),
            (2,"Patients with broken Arms")
           ]
patients.sort(key = lambda x: x[0])

while patients:
    priority,patient = patients.pop(0)
    print(f"Attending to: {patient} (priority {priority})")
# Out:
# Attending to: Patients with heart attack (priority 1)
# Attending to: Patients with broken Arms (priority 2)
# Attending to: Patients with cold (priority 3)

# %% [markdown]
# # Dequeue
# 1.insert at front(appendleft())
#
# 2.insert at rear(append())
#
# 3.remove from front(popleft())
#
# 4.remove from rear(pop())

# %%
# Dequeue example
class deque:
    def __init__(self):
        self.items =[]
    def isEmpty(self):
        return self.items == []

    def addRear(self,item):
        self.items.append(item)
    def addFront(self,item):
        self.items.insert(0,item)
    def removeRear(self):
        return self.items.pop()
    def removeFront(self):
        return self.items.pop(0)
d = deque()
print(d.isEmpty())
d.addRear(1)
print(d.items)
d.addFront(2)
print(d.items)
d.addFront(3)
print(d.items)
d.removeRear()
print(d.items)
d.addFront(4)
print(d.items)
d.addFront(5)
print(d.items)
d.addFront(6)
print(d.items)
d.removeFront()
print(d.items)

"""from queue import deque
print(dir(deque))"""

from collections import deque
print(dir(deque))

q = deque([1,2,3])
q.append(45)
q.appendleft(34)
print(q)
q.pop()
q.popleft()
print(q)
# Out:
# True
# [1]
# [2, 1]
# [3, 2, 1]
# [3, 2]
# [4, 3, 2]
# [5, 4, 3, 2]
# [6, 5, 4, 3, 2]
# [5, 4, 3, 2]
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__copy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'appendleft', 'clear', 'copy', 'count', 'extend', 'extendleft', 'index', 'insert', 'maxlen', 'pop', 'popleft', 'remove', 'reverse', 'rotate']
# deque([34, 1, 2, 3, 45])
# deque([1, 2, 3])

# %% [markdown]
# # Linked_List
# --Linear data structure.
#
# ## ** Types Of LL**
# 1.singly LL.
# 2.Doubly LL.
# 3.Circular LL.
#
# ## Opertion:
# 1.Traverse
# 2.Insert
# 3.Deletion
# 4.Searching

# %%
# Singly linked list
class Node:
    #Create node
    def __init__(self,items):
        self.items = items
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    linked_list = LinkedList()
    
    #Assign item values
    linked_list.head = Node(1)
    second = Node(2)
    third = Node(3)

    #Connect the nodes
    linked_list.head.next = second
    second.next = third

    #Print the Linked List Item
    while linked_list.head != None:
        print(linked_list.head.items,end=" ")
        linked_list.head = linked_list.head.next
# Out:
# 1 2 3

# %%
# Doubly Linked List

class Node:
    #Create node
    def __init__(self,item):
        self.item = item
        self.prev = None
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    dll = DoublyLinkedList()

    #Assign the Values
    dll.head = Node(1)
    second = Node(2)
    third = Node(3)

    #connect nodes(forward)
    dll.head.next = second
    second.next = third

    # connect nodess(Backward)
    second.prev = dll.head
    third.prev = second

    #print the Doubly LL
    temp = dll.head
    while temp is not None:
        print(temp.item,end=" ")
        temp = temp.next
# Out:
# 1 2 3

# %%
class node:
    def __init__(self, value):
        self.value = value
        self.next = None

class linkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    l1 = linkedList()

    l1.head = node(1)
    second = node(2)
    third = node(3)

    l1.head.next = second
    second.next = third

    count = 0
    while l1.head != None:
        count += 1
        l1.head = l1.head.next
    print(count)
# Out:
# 3

# %%
# Circular Linked list
class Node:
    #Create node
    def __init__(self,item):
        self.item = item
        self.prev = None
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    dll = DoublyLinkedList()


#Assign the Values
    dll.head = Node(1)
    second = Node(2)
    third = Node(3)

#connect nodes(forward)
    dll.head.next = second
    second.next = third
    third.next = dll.head

#print the Doubly LL
    temp = dll.head
    while True:
        print(temp.item,end=" ")
        temp = temp.next
        if temp == dll.head:
            break
# Out:
# 1 2 3

# %%
# Insersting Element
class node:
    def __init__(self, value):
        self.value = value
        self.next = None

class linkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    l1 = linkedList()

    node1 = node(1)
    node2 = node(2)
    node3 = node(3)

    head = node1
    node1.next = node2
    node2.next = node3

    # at beginning
    new_node = node(4)
    new_node.next = head
    head = new_node

    # At end
    new_node1 = node(5)
    node3.next = new_node1

    # at middle
    new_node_mid = node(2.5)

    current = head
    count = 0
    target = 3
    while count is not target:
        count += 1
        if count == 3:
            node2.next = new_node_mid
            new_node_mid.next = node3
            

    while current is not None:
        print(current.value, end=' ')
        current = current.next
# Out:
# 4 1 2 2.5 3 5

# %%
# To delete the last item from linked list


class node:
    def __init__(self, value):
        self.value = value
        self.next = None

class linkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    l1 = linkedList()

    node1 = node(1)
    node2 = node(2)
    node3 = node(3)

    head = node1
    node1.next = node2
    node2.next = node3

    current = head
    current1 = current.next
    while current is not None:
        print(current.value, end=' ')

        if current1.next == None:
            current.next = None

        current = current.next
        current1 = current1.next
# Out:
# 1 2

# %%
# To search a specific item in singly linked list and return true if the item is found otherwise return False

class node:
    def __init__(self, value):
        self.value = value
        self.next = None

class linkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    l1 = linkedList()

    node1 = node(1)
    node2 = node(2)
    node3 = node(3)

    head = node1
    node1.next = node2
    node2.next = node3

    target = 5

    current = head
    while current is not None:
        if current.value == target:
            print('True')
            break
        else:
            if current.next == None:
                print("False")
                break
            else:
                current = current.next
# Out:
# False

# %%
# To print a given doubly linked list in reverse order

class node:
    def __init__(self, value):
        self.value = value
        self.next = None
        self.previous = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

if __name__ == "__main__":
    dll = DoublyLinkedList()
    
    dll.head = node(1)
    second = node(2)
    third = node(3)

    # forward
    dll.head.next = second
    second.next = third

    # backward
    second.previous = dll.head
    third.previous = second

    temp = third
    while temp is not None:
        print(temp.value, end=" ")
        temp = temp.previous
# Out:
# 3 2 1
