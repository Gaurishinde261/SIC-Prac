# %% [markdown]
# # Dictornary

# %%
## Dictnoary is mutable unoredred collections of data store a value in key-value pairs

## why dict is important is industry?
### API response (JSON)
database record
congiguration files
user profile

## Charc
key value pair
muttable 
Orderd(new version)
Duplicate key not allowed values are allowed 
Indexing

# %%
dict1={'name':'John','age':30,'city':'New York'}
print(dict1['name'])
print(dict1['age'])
# Out:
# John
# 30

# %%
dict1['na']="Hello"
print(dict1)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York', 'na': 'Hello'}

# %%
#Update

# %%
dict1['name']="Ram"
print(dict1)
# Out:
# {'name': 'Ram', 'age': 30, 'city': 'New York', 'na': 'Hello'}

# %% [markdown]
# # Remove Item
# ## we can remove item using del keyword or pop() method
# ## using del to remove a key-value pair
# ## using pop() to remove an item and get its value

# %%
del dict1['city']
print(dict1)
# Out:
# {'name': 'Ram', 'age': 30, 'na': 'Hello'}

# %%
age = dict1.pop('age')
print(age)
print(dict1)
# Out:
# 30

# %% [markdown]
# ## Getting keys values and items
# keys:get a list of all keys
# values:get a lis of all values'
# items: Get key value pair

# %%
#dict2={'name':'Alice

# %%
##clear all items
to remove items from the dictnary,use the clear() method
##dict2.clear()
print(dict2)

# %% [markdown]
# ## Merge two dictonary

# %%
dict3={'name':'John'}
dict4={'age':30}
dict3.update(dict4)
print(dict3)
# Out:
# {'name': 'John', 'age': 30}

# %%
nested_dict= {
    'person':{'name':'John','age':31},
    'address':{'city':'New york','zip':'1001'} }
print(nested_dict)
# Out:
# {'person': {'name': 'John', 'age': 31}, 'address': {'city': 'New york', 'zip': '1001'}}

# %%
c = nested_dict['person']['age']
d = nested_dict['address']['zip']
print(c)
print(d)
# Out:
# 31
# 1001

# %% [markdown]
# ### **Use get() to access a value a nd avoid keyerror.if the key dosent exit,it returns none(or defalut value)

# %%
a={'ni':"Nikhil","av":"avanti"}
dict1={'name':'anuragh','age':30,'city':'pune'}
name= dict1.get("na")
print(dict1)
print(name)
# Out:
# {'name': 'anuragh', 'age': 30, 'city': 'pune'}
# None

# %%
# copy dictnory

# %%
orginal_dict = ['name':'john']
copied_dict=original_dict.copy()
print(copied
