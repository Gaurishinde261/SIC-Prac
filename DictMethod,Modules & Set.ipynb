# %% [markdown]
# # Day 10
# # 14/11/25

# %%
tp={
    'Mercury':{
        'mrd':2439.7,
        'mass':3.3022E+23,
        'op':87.969
    },
    'Venus':{
        'mrd':6051.8,
        'mass':4.8676E+24,
        'op':224.70069,
    },
    'Earth':{
        'mrd':6371.0,
        'mass':5.97219E+24,
        'op':365.25641,
    }
}
print(tp['Venus']['mrd'])
print(tp)
# Out:
# 6051.8
# {'Mercury': {'mrd': 2439.7, 'mass': 3.3022e+23, 'op': 87.969}, 'Venus': {'mrd': 6051.8, 'mass': 4.8676e+24, 'op': 224.70069}, 'Earth': {'mrd': 6371.0, 'mass': 5.97219e+24, 'op': 365.25641}}

# %%
x={'a':0,'b':0,'c':0,'d':0}
y=x

# %%
x is y
# Out:
# True

# %%
y
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0}

# %%
x={'a':0,'b':0,'c':0,'d':0}

# %%
y = x.copy()

# %%
x is y
# Out:
# False

# %%
x == y
# Out:
# True

# %%
x = {'a':{'python':'2.7'},'b':{'python':'3.6'}}
import copy
y = copy.deepcopy(x)
y['a']['python'] = '2.7.15'
x
# Out:
# {'a': {'python': '2.7'}, 'b': {'python': '3.6'}}

# %%
y
# Out:
# {'a': {'python': '2.7.15'}, 'b': {'python': '3.6'}}

# %% [markdown]
# # Module

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 11, 14, 15, 52, 54, 520969)

# %%
today = datetime.date.today()
print(today)
# Out:
# 2025-11-14

# %%
today
# Out:
# datetime.date(2025, 11, 14)

# %%
today.year
# Out:
# 2025

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
st=datetime.datetime.now()
st.replace(month = 12,day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 15, 56, 53, 52689)

# %%
import datetime as dt
st=dt.datetime.now()
st.replace(month = 12,day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 15, 59, 31, 320067)

# %%
from datetime import datetime
st=datetime.now()
st.replace(month = 12,day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 16, 2, 38, 465360)

# %%
from datetime import *
today = date.today()
today
# Out:
# datetime.date(2025, 11, 14)

# %%
import time
seconds = time.time()
print('Time after epoxy=',seconds) #from 1970 jan 1 till date seconds
# Out:
# Time after epoxy= 1763116550.6687083

# %%
import time 
unixtime=time.time()
local_time=time.localtime(unixtime)
local_time
# Out:
# time.struct_time(tm_year=2025, tm_mon=11, tm_mday=14, tm_hour=16, tm_min=10, tm_sec=44, tm_wday=4, tm_yday=318, tm_isdst=0)

# %%
import time
unix_timestamp = time.time()
local_time = time.localtime(unix_timestamp)
print(time.strftime('%Y-%m-%d %H:%M:%S',local_time))
# Out:
# 2025-11-14 18:09:45

# %% [markdown]
# ## Math Module

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import math as m
m.pow(3,3)
# Out:
# 27.0

# %%
import math as m
m.pow(3,3)
# Out:
# 27.0

# %%
m.fabs(-99)
# Out:
# 99.0

# %%
m.ceil(2.1)
# Out:
# 3

# %%
m.ceil(-2.1)
# Out:
# -2

# %%
m.floor(2.1)
# Out:
# 2

# %%
m.log(2.71828)
# Out:
# 0.999999327347282

# %%
m.log(100,10)
# Out:
# 2.0

# %%
import math as m
m.sin(0.0)
# Out:
# 0.0

# %%
m.sin(90.0)
# Out:
# 0.8939966636005579

# %%
m.sin(m.pi/2)
# Out:
# 1.0

# %% [markdown]
# # Set

# %%
numbers={1,2,3}
numbers.add(4)
numbers
# Out:
# {1, 2, 3, 4}

# %%
numbers = {2,3,1}
if 1 in numbers:
    print("1 is in the set")
# Out:
# 1 is in the set

# %%
set([1,2,3,1,2])
# Out:
# {1, 2, 3}

# %%
set("abcdefg")
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f', 'g'}

# %%
numbers = set()
numbers
# Out:
# set()

# %%
s1={1,2,3,4,5,6}

# %%
s2={4,5,6,7,8,9}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1 & s2
# Out:
# {4, 5, 6}

# %%
s1 - s2
# Out:
# {1, 2, 3}

# %%
s1 ^ s2
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
s1={1,2,3,4,5,6}

# %%
s2={4,5,6,7,8,9}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.intersection(s2)
# Out:
# {4, 5, 6}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
s1 = {1,2,3,4,5,6}

# %%
s2={4,5,6,7,8,9}

# %%
s3={5,6,9,10,11}

# %%
s1 & s2 & s3
# Out:
# {5, 6}

# %%
s1 - s2 - s3
# Out:
# {1, 2, 3}

# %%
s1 = {1,2,3,4,5}
s2 = {1,2,3}
s3 = {1,2,6}

# %%
s2.issubset(s1)
# Out:
# True

# %%
s3.issubset(s1)
# Out:
# False

# %%
s1.issuperset(s2)
# Out:
# True

# %%
s1.issuperset(s3)
# Out:
# False

# %%
s1 = {1,2,3}
s2 = {10,20,30}
s1.isdisjoint(s2)
# Out:
# True

# %%
A = {1,2,3}
B = {1,2,3}
A == B
# Out:
# True

# %%
A = {1,2,3,4,5}
B = {1,2,3}
B <
