# %% [markdown]
# # Day 6
# # 10/11/2025

# %% [markdown]
# ### Sequence datatypes in python

# %% [markdown]
# ### List and Tuple dataTypes

# %% [markdown]
# ### List :
# List is of mutable type
# Duplication can be done
#
# ### Dictionary necessity in list:
# 1.Dict dattypeis pair of Key Value
# 2.Use to express paired information

# %%
person1 =['David Doe',20,1,180.0,100.0]
person2 =['John Smith',25,1,170.0,70.0]
person3 =['Jane Carter',22,0,160.0,60.0]
person4 =['Peter Kelly',40,1,150.0,50.0]

person_list = person1 + person2 + person3 + person4 

n_persons = int(len(person_list)/5)
age_sum = 0.0
for  age in person_list[1::5]:
    age_sum += age
avg = float(age_sum)/n_persons
print('The Average age is', str(avg))
# Out:
# The Average age is 26.75

# %%
d={ 'Name':'Gauri',
    'age':'21',
    'Div': 'B'
  }
print(d.keys())
print(d.values())
# Out:
# dict_keys(['Name', 'age', 'Div'])
# dict_values(['Gauri', '21', 'B'])

# %% [markdown]
# #### List and index

# %%
fruits=['banana','Apple','Orange','Kiwi']
print(fruits)
mixed_list=[100,200,"Apple",400]
print(mixed_list)
# Out:
# ['banana', 'Apple', 'Orange', 'Kiwi']
# [100, 200, 'Apple', 400]

# %% [markdown]
# #### List using Range Function Also Indexing

# %%
list1 = list(range(1,10))
list1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
list1 = [11,22,33,44,55,66]
print(list1)
print(len(list1))
# Out:
# [11, 22, 33, 44, 55, 66]
# 6

# %%
list1[0]
# Out:
# 11

# %%
list1[1]
# Out:
# 22

# %%
list1[-1]
# Out:
# 66

# %%
list1[-2]
# Out:
# 55

# %%
list1[-3]
# Out:
# 44

# %% [markdown]
# #### Merging Two list

# %%
p1 =['Ram',20,1,180.0,100.0]
p2 =['Mohan',25,1,170.0,70.0]

person_list= p1+p2
print(person_list)
# Out:
# ['Ram', 20, 1, 180.0, 100.0, 'Mohan', 25, 1, 170.0, 70.0]

# %% [markdown]
# #### Append,Extend,del,pop, a list

# %%
list1=['a','b','c','d','e']
list1.append('f')
list1
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
list1=[10,20,30,40]
list1.append(50)
list1
# Out:
# [10, 20, 30, 40, 50]

# %%
list1=['a','b','c','d','e']
list2=[1,2,3]
list1.extend(list2)
list1
# Out:
# ['a', 'b', 'c', 'd', 'e', 1, 2, 3]

# %%
list1.extend('g')
list1
# Out:
# ['a', 'b', 'c', 'd', 'e', 1, 2, 3, 'g']

# %%
list1 = [11,22,33,44,55,66]
print(list1)

del list1[2]
print(list1) # pop to be added
# Out:
# [11, 22, 33, 44, 55, 66]
# [11, 22, 44, 55, 66]

# %%
list1.remove(44)
list1
# Out:
# [11, 22, 55, 66]

# %%
list1[-7:-2]
# Out:
# [11, 22, 33, 44]

# %%
list3=[10,20,30,40,50]
10 in list3
# Out:
# True

# %%
60 in list3
# Out:
# False

# %%
10 not in list3
# Out:
# False

# %%
50 not in list3
# Out:
# False

# %%
for n in list3:
    print(n,end=' ')
# Out:
# 10 20 30 40 50

# %%
list2 =[11,22,33,44,55,66]
if(55 in list2):
    list2.remove(55)
if (88 in  list2):
    list2.remove(88)
print(list2)
# Out:
# [11, 22, 33, 44, 66]

# %%
list4 =['ram',178.9,'shyam',173.5,'mohan',176.1]
print(list4)
list4.insert(4,"Gopal")
list4.insert(5,168.1)
print(list4)
# Out:
# ['ram', 178.9, 'shyam', 173.5, 'mohan', 176.1]
# ['ram', 178.9, 'shyam', 173.5, 'Gopal', 168.1, 'mohan', 176.1]

# %% [markdown]
# ## Tuple

# %% [markdown]
# ## Tuple is of immutable
#
# Methods:
# 1.count:count the no element in tuple
# 2.Index:

# %%
d1 = {'name':'ram','age':20}

# %%
d2 = {'age':20,'name':'ram'}

# %%
d1==d2
# Out:
# True

# %%
d1 !=d2
# Out:
# False

# %%
Person = {'name':'ram','age':20,'weight':26}

# %%
Person['job']='Data Scientist'

# %%
Person
# Out:
# {'name': 'ram', 'age': 20, 'weight': 26, 'job': 'Data Scientist'}

# %%
Person = {'name':'ram','age':20,'weight':26}

# %%
Person['age']=27

# %%
Person
# Out:
# {'name': 'ram', 'age': 27, 'weight': 26}

# %%
import json

data = {
    "name": "Ram",
    "age": 25,
    "hobby": ["Basketball"],
    "family": {"father": "Mohan", "mother": "Laxmi"},
    "married": True
}

json_string = json.dumps(data)

json_data = json.loads(json_string)

print(type(json_data))
print(json_data['name'])
print(json_data['family'])
print(json_data['married'])
# Out:
# <class 'dict'>
# Ram
# {'father': 'Mohan', 'mother': 'Laxmi'}
# True
