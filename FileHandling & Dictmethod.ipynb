# %% [markdown]
# # Day 8
# # 12/11/2025

# %%
f = open('Hello.txt','w')
f.write('Hello world Here!')
f.close()

# %%
f = open('Hello.txt','w')

# %%
f = open('Hello.txt','wt')

# %%
f = open('Hello.txt','wb')

# %%
f = open('Hello.txt','r+t')

# %%
f=open('Hello.txt','w+t')

# %%
f=open('Hello.txt','a+t')

# %%
f.write("Hello world!!")
# Out:
# 13

# %%
f.write('love of my life,you\'ve hurt me\n')
f.write('you hsve broken my heart and now you leave me\n')
f.write('love of my life,can\'t you see?\n')
# Out:
# 31

# %%
f = open('hello.txt','r')
s=f.read()
print(s)
f.close()
# Out:
# Hello world!!love of my life,you've hurt me
# you hsve broken my heart and now you leave me
# love of my life,can't you see?

# %%
f = open('hello.txt','r')
s=f.readline()
print(s,end='')
s=f.readline()
print(s,end='')
f.close()
# Out:
# Hello world!!love of my life,you've hurt me
# you hsve broken my heart and now you leave me

# %%
str1=['a','b','c','b','a','b','c']
dic = {}
for ch in str1:
    if ch not in dic.keys():
        dic[ch]=0
    dic[ch] += 1
print('alphabet counting:',dic)
# Out:
# alphabet counting: {'a': 2, 'b': 3, 'c': 2}

# %%
str1=['a','b','c','b','a','b','c']
dic = {}
for ch in str1:
    dic.setdefault(ch,0)
    dic[ch] += 1
    print(list(dic.items()))
print('alphabet counting:',dic)
# Out:
# [('a', 1)]
# [('a', 1), ('b', 1)]
# [('a', 1), ('b', 1), ('c', 1)]
# [('a', 1), ('b', 2), ('c', 1)]
# [('a', 2), ('b', 2), ('c', 1)]
# [('a', 2), ('b', 3), ('c', 1)]
# [('a', 2), ('b', 3), ('c', 2)]
# alphabet counting: {'a': 2, 'b': 3, 'c': 2}

# %%
dic ={'a':10,'b':20,'c':30,'d':40}
dic.setdefault('f',50)
print(dic)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'f': 50}

# %%
dic ={'a':10,'b':20,'c':30,'d':40}
dic.update(d=90)
print(dic)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 90}

# %%
dic.update(e=50)
print(dic)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 90, 'e': 50}
